# %%
print("hello");
# Out:
# hello

# %%
print("ali hasssan" ,"my age is 21");
# Out:
# ali hasssan my age is 21

# %%
print(120*10)
# Out:
# 1200

# %%
name= "Ali";
age= 21;
price= 12;
total= age*price ;
print("my name is " , name);
print("multiplication of age and price" , total);
print ("my age is " ,age);
print("iam cs student of computer science")
age2=age;
print(age2)
print(type , (price))
a=5;
b= a*a;
print(b)
c= 5;
d = 10;
sum= c + d ;
print (sum);
print(d-c)
print(c*d);
print(c%d);
print(c**d);
print(c!=d);
print(c>=d)
print(c<=d)
e = d / c ;
print(e)
d**= 5
print (d);
print("iam learing python from scratch")
print (not(c>d));
# Out:
# my name is  Ali
# multiplication of age and price 252
# my age is  21
# iam cs student of computer science
# 21
# <class 'type'> 12
# 25
# 15
# 5
# 50
# 5
# 9765625
# True
# False
# True
# 2.0
# 100000
# iam learing python from scratch
# True

# %%
#operators
print(not False);
print(not True);
val1 = True
val2 = True
print("answer of oR is " , c==d or val2)
print("we can use conditions also so here it is " , (c==d) or (c<d))
z = int("2");
m= c+z;
print (m);
# Out:
# True
# False
# answer of oR is  True
# we can use conditions also so here it is  True
# 7

# %%
# get inputs from user
name= (input("enter your name "))
age= int (input ("please enter your age "))
marks = int(input("please enter your your marks "))
print("name=", name , "age=" , age , "marks=" , marks)
# Out:
# enter your name ali
# please enter your age 12
# please enter your your marks 12
# name= ali age= 12 marks= 12

# %%
# an easy program to add two numbers
# we must declare data type otherwise it will treat it like string and just JOIN two numbers like 5 + 2 = 52 , but we need 7 ..........
num1= int(input(("please enter a number")))
num2= int(input(("please enter 2nd number")))
num3 = num1 + num2 ;
print("The sum of two numbers is " , num3 )
print("program successful");
# Out:
# please enter a number6
# please enter 2nd number2
# The sum of two numbers is  8
# program successful

# %%
# write a program to get sides of square from user and print its area
val1= int(input("please enter first side of square"))
val2= int(input("please enter second side of square"))
val3 = val1 * val2
print("The Area of Square is " , val3)
print("program successful")
# Out:
# please enter first side of square12
# please enter second side of square12
# The Area of Square is  144
# program successful

# %%
# input two floating values and print their average
val1= float(input("please enter first number "))
val2= float(input("please enter second number "))
val3 = (val1 + val2) / 2 ;
print("The Evarage of two numbers is " , val3)
print("program Successful")
# Out:
# please enter first number 20
# please enter second number 20
# The Evarage of two numbers is  20.0
# program Successful

# %%
# input 2 number and print true if a is greater that or equal to b , otherwise false
a= int(input("please enter first number a "))
b= int(input("please enter second number b "))
print(a>=b)
print("program Successful")
# Out:
# please enter first number a 2
# please enter second number b 1
# True
# program Successful
