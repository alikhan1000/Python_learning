# %%
# Length of string , indexing
str = "this is a string"
cb = str[4]
ch = str[5]
cf= str[6]
print(len(str))
print(str[2])
#print(cb)
print(cf)
#slicing
print("slicing string is" , str[-1:-16])
print("slicing string is" , str[0:len(str)])
print("slicing string is" , str[0:])
# Out:
# 16
# i
# s
# slicing string is
# slicing string is this is a string
# slicing string is this is a string
